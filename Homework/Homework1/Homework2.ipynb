# %% [markdown]
# # Homework #2
#
# ## Create a Farm
#
# Old McDonald is dyslexic OIEIE...
# Please help on his farm, please...
#
# Your goal is to categorize all of his animals into groups.
# example:
# - pigs are useful for there meat, skin and help improve the soil and biodiversity
#
# Create classes for all of his different types of animals
# You should have at least 5 animals on the farm ie. cows, pigs, dogs, goats
#
# VERY Poorly written example
#
# ```python
# class Animals (self):
#     self.name = name
#     self.age = age
#
# class Pets(Animals):
#     self.friend = True
#     self.eat = False
#
# class Farm (Animals):
#     self.eat = True #will it be sold for food
#     self.leather = True #will it be sold for leather
#     self.helper = False #will it be used to say plow a field
#     self.soil = True #Will it be used to help the soil
#
# class Dog(Pets)
#     self.good_boy = True
#     self.type = "type of dog"
# listOfAnimals = [Dog()]
# ```
#
#
# Your program should have an input and output allowing the user to add and remove animals.
#
# Love you !

# %%
class Animals:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Livestock(Animals):
    def __init__(self, name, age, meat, milk, hide, manure, fabric, eggs):
        super().__init__(name, age)
        self.meat = meat
        self.milk = milk
        self.hide = hide
        self.manure = manure
        self.fabric = fabric
        self.eggs = eggs

class Work(Animals):
    def __init__(self, name, age, labor, herding, landcontrol):
        super().__init__(name, age)
        self.labor = labor
        self.herding = herding
        self.landcontrol = landcontrol

class Pets(Animals):
    def __init__(self, name, age, friend):
        super().__init___(name, age)
        self.friend = friend


class Cow(Livestock):
    def _init__(self, name, age):
        super().__init__(name, age, meat=True, milk=True, hide=True, manure=True, fabric=False, eggs=False)

class Pig(Livestock):
    def __init__(self, name, age):
        super().__init__(name, age, meat=True, milk=False, hide=False, manure=True, fabric=False, eggs=False)

class Chicken(Livestock): 
    def __init__(self, name, age):
        super().__init__(name, age, meat=True, milk=False, hide=False, manure=True, fabric=False, eggs=False)

class Goat (Livestock, Work):
    def __init__(self, name, age):
        super().__init__(name, age, meat=True, milk=True, hide=True, manure=True, fabric=True, eggs=False, labor=False, herding=False, landcontrol=True)

class Sheep (Livestock, Work):
    def __init__(self, name, age):
        super().__init__(name, age, meat=True, milk=False, hide=False, manure=True, fabric=True, eggs=False, labor=False, herding=False, landcontrol=True)

class Horse (Pets, Work):
    def __init__(self, name, age):
        super().__init__(name, age, labor=True, herding=False, landcontrol=False, friend=True)
class Dog (Pets, Work):
    def __init__(self, name, age):
        super().__init__(name, age, labor=True, herding=True, landcontrol=False, friend=True)

#the code below was from chatgpt, I was confused on how to make the list input and output

class Farm:
    def __init__(self):
        self.listOfAnimals = []

    def add_animal(self, animal):
        self.listOfAnimals.append(animal)
        print("{animal.name} has been added to the farm")
    
    def remove_animal(self, name):
        animal_to_remove = None
        for animal in self.listOfAnimals:
            if animal.name == name:
                animal_to_remove = animal
                break
            if animal_to_remove:
                self.listofAnimals.remove(animal_to_remove)
                print("{animal.name} has been removed from the farm")
        else:
            print(" No animal with the name {name} found.")

    def show_animals(self):
        if not self.listOfAnimals:
            print("No animals on the farm.")
        else:
            for animal in self.listOfAnimals:
                print(f"{animal.name} - {type(animal).__name__} - Age: {animal.age}")

def user_interaction(farm):
    while True:
        print("\nFarm Menu:")
        print("1. Add animal")
        print("2. Remove animal")
        print("3. View animals")
        print("4. Exit")
        
        choice = input("Please choose an option (1-4): ")

        if choice == "1":
            animal_type = input("Enter the animal type (Cow, Pig, Chicken, Goat, Sheep, Horse, Dog): ").capitalize()
            name = input("Enter the animal's name: ")
            age = input("Enter the animal's age: ")

            if animal_type == "Cow":
                farm.add_animal(Cow(name, age))
            elif animal_type == "Pig":
                farm.add_animal(Pig(name, age))
            elif animal_type == "Chicken":
                farm.add_animal(Chicken(name, age))
            elif animal_type == "Goat":
                farm.add_animal(Goat(name, age))
            elif animal_type == "Sheep":
                farm.add_animal(Sheep(name, age))
            elif animal_type == "Horse":
                farm.add_animal(Horse(name, age))
            elif animal_type == "Dog":
                farm.add_animal(Dog(name, age))
            else:
                print("Invalid animal type. Please try again.")
        
        elif choice == "2":
            name = input("Enter the name of the animal to remove: ")
            farm.remove_animal(name)
        
        elif choice == "3":
            farm.show_animals()
        
        elif choice == "4":
            print("Exiting the program.")
            break
        
        else:
            print("Invalid option. Please choose again.")

if __name__ == "__main__":
    farm = Farm()
    user_interaction(farm)
# Out:
# Farm Menu:
# 1. Add animal
# 2. Remove animal
# 3. View animals
# 4. Exit
# {animal.name} has been added to the farm
#
# Farm Menu:
# 1. Add animal
# 2. Remove animal
# 3. View animals
# 4. Exit
# tom - Pig - Age: 3
#
# Farm Menu:
# 1. Add animal
# 2. Remove animal
# 3. View animals
# 4. Exit
# {animal.name} has been added to the farm
#
# Farm Menu:
# 1. Add animal
# 2. Remove animal
# 3. View animals
# 4. Exit
# tom - Pig - Age: 3
# jalissa - Chicken - Age: 3
#
# Farm Menu:
# 1. Add animal
# 2. Remove animal
# 3. View animals
# 4. Exit
# tom - Pig - Age: 3
# jalissa - Chicken - Age: 3
#
# Farm Menu:
# 1. Add animal
# 2. Remove animal
# 3. View animals
# 4. Exit
# tom - Pig - Age: 3
# jalissa - Chicken - Age: 3
#
# Farm Menu:
# 1. Add animal
# 2. Remove animal
# 3. View animals
# 4. Exit
# tom - Pig - Age: 3
# jalissa - Chicken - Age: 3
#
# Farm Menu:
# 1. Add animal
# 2. Remove animal
# 3. View animals
# 4. Exit
#
# Farm Menu:
# 1. Add animal
# 2. Remove animal
# 3. View animals
# ...
